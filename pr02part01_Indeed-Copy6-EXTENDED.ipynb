# %%
# for multiple output on Jupyter notebook
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# to open the web page for web scraping
import requests

# to parse html 
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time
# selenium or splinter for 
from splinter import Browser
import numpy as np

# %%
def compile_URL(job,city):
    """
    """
    base_url = 'http://www.indeed.com/jobs?q='
    add_1_job= job
    add_precity = '&l='
    add_2_city=city
    return (base_url + add_1_job + add_precity + add_2_city)

# %%
# print(compile_URL('developer','denver'))

# %%
def bring_soup(url):
    html_source= requests.get(url)
    soup = BeautifulSoup(html_source.content, 'html.parser', from_encoding="utf-8")
    return soup

# %%
# soup = bring_soup(compile_URL('developer','denver'))

# %%
def title_column(soup):
    col_title =[]
    for itersoup in soup.find_all(class_= "result" ):
        # - - - - 
        try:
            itertitle = itersoup.find(class_='jobtitle').\
            text.replace('\n', '')
        except:
            itertitle='None'
        # - - - - 
        col_title.append(itertitle)
        
    return col_title

# %%
# title_column(soup)

# %%
def location_column(soup):
    col_location  = [ ]
    for itersoup in soup.find_all(class_= "result" ):
            try:
                location = itersoup.find('span', {'class':"location" }).\
                text.replace('\n', '')
            except:
                location = 'None'
#             - - -
            col_location.append(location)
    return col_location

# %%
# location_column(soup)

# %%
def company_column(soup):
    col_company  = [ ]
    for itersoup in soup.find_all(class_= "result" ):
            try:
                company = itersoup.find(class_='company').\
                text.replace('\n','')
            except:
                company = 'None'
#             - - -
            col_company.append(company.strip())
    return col_company

# %%
# company_column(soup)

# %%
def desc_column(soup):
    col_desc  = [ ]
    for itersoup in soup.find_all(class_= "result" ):
            try:
                description = itersoup.find('span', {'class':'summary'}).\
                text.replace('\n', '')
            except:
                description = 'None'
#             - - -
            col_desc.append(description.strip())
    return col_desc

# %%
# desc_column(soup)

# %%
def url_column(soup):
    col_href = []
    base_url = 'http://www.indeed.com'
    for iterfoo in soup.find_all(class_= "result" ):
        try:
            href = iterfoo.find('a')['href']
            col_href.append((base_url+href).strip())
        except:
            href='None'
            col_href.append(href)
        
    return list(col_href)
    #     print('http://www.indeed.com'+href)

# %%
def frame_indeed(soup):
    """ this function still can not make soup """
    return pd.DataFrame({'Title': title_column(soup),
              'Company': company_column(soup),
              'Location': location_column(soup),
              'Description': desc_column(soup),
              'URLs': url_column(soup)})

# %%
# this is the main function of our app's JobLister module
# ====================================
# compile_URL('developer','denver')
def parse_n_frame(url):
#     /*  this function brings soup herself  */
    soup = bring_soup(url)
    return pd.DataFrame({'Title': title_column(soup),
              'Company': company_column(soup),
              'Location': location_column(soup),
              'Description': desc_column(soup),
              'URLs': url_column(soup)})
#============end==============

#===========test==============
# parse_n_frame(dev_denver_url)

# %%
jobListSample = ['data+analyst',
            'developer',
            'programmer',
            'front+end+developer',
            'back+end+developer',
            'full+stack+developer'
           ]

# %%
cityListSample = ['denver',
                  'boulder',
             'phoenix',
             'houston',
             'tucson',
             'chicago',
             'new+york',
             'albuquerque',
             'seattle',
             'san+francisco'
             ]

# %%
def scrapListFrame(job_list, city_list):
    pass 
    list_of_all_frames =[]
    for job in job_list:
        for city in city_list:
            __url__ = compile_URL(job,city)
            __df__= parse_n_frame(__url__)
            __df__['cityJob']=city
            __df__['cityJob']=__df__['cityJob'].str.replace('+',' ')
            list_of_all_frames.append(__df__)
       
    return pd.concat(list_of_all_frames)
# -----------------

# %%
scrapListFrame(jobListSample,cityListSample)
# returns dataframe apprx 1,000 rows
# Out:
#                                                 Title  \
# 0                                        Data Analyst
# 1                  Business Intelligence Data Analyst
# 2                                        Data Analyst
# 3   Data Analyst, Client Experience - Spectrum Ent...
# 4                                        Data Analyst
# 5                       Remote Freelance Data Analyst
# 6                                        Data Analyst
# 7                                        Data Analyst
# 8                                        Data Analyst
# 9                                Signal /Data Analyst
# 10                                       Data Analyst
# 11                                       Data Analyst
# 12                             Associate Data Analyst
# 13  Statewide Regional Center Research & Data Analyst
# 14                                       Data Analyst
# 15                                     Data Analyst I
# 0                                        Data Analyst
# 1                                        Data Analyst
# 2                                        Data Analyst
# 3   Digital Media Analyst -- Recruitment Advertisi...
# 4                    Laboratory Analyst (Greeley, CO)
# 5                              Associate Data Analyst
# 6                                        Data Analyst
# 7         Customer Insights Data Analyst (Green Chef)
# 8                                        Data Analyst
# 9   Business Continuity and Resilience Analyst, Gl...
# 10                                       Data Analyst
# 11                                       Data Analyst
# 12                                       Data Analyst
# 13                              Business/Data Analyst
# ..                                                ...
# 4            Senior SW Engineer, Full Stack Developer
# 5                                Full stack developer
# 6                         Junior Full Stack Developer
# 7                       Software Development Engineer
# 8                       Software Development Engineer
# 9                        Full Stack Software Engineer
# 10                                       BI DEVELOPER
# 11                          JUNIOR SOFTWARE DEVELOPER
# 12                       Full Stack Software Engineer
# 13                                  Software Engineer
# 14  Marketplace Fares - Backend Software Engineer ...
# 15  BEST Company Culture - Full Stack Small Team J...
# 16       Full Stack Developer - Node.js and databases
# 0                                Full Stack Developer
# 1                 Full Stack Engineer-JavaScript/Java
# 2                Full Stack Developer - Ruby on Rails
# 3                         Senior Full Stack Developer
# 4                                 Full Stack Engineer
# 5   Junior React / Full Stack Developer - San Fran...
# 6                                Full Stack Developer
# 7                       Software Engineer, Full Stack
# 8                        Full Stack Software Engineer
# 9                                 Full Stack Engineer
# 10                               Full Stack Developer
# 11                     Internationalization Developer
# 12                  Software Engineer, Square Payroll
# 13                               Full Stack Developer
# 14                               Full stack Developer
# 15                       Full Stack Software Engineer
# 16   Liquid Studios - Full-Stack JavaScript Developer
#
#                                   Company  \
# 0                                ANB Bank
# 1                                    DISH
# 2                         Clinica Tepeyac
# 3                                Spectrum
# 4                           HCA Corporate
# 5                          Cardwell Beach
# 6                    DaVita Medical Group
# 7                         Clinica Tepeyac
# 8                      Concept Technology
# 9             LOCKHEED MARTIN CORPORATION
# 10                      AAS Services, LLC
# 11                   Cherry Creek Schools
# 12                           healthgrades
# 13    State of Colorado Job Opportunities
# 14                             System One
# 15                          Computershare
# 0                                ANB Bank
# 1                              System One
# 2                        Procare Software
# 3                           KRT Marketing
# 4   IEH Laboratories and Consulting Group
# 5                        West Corporation
# 6                           HCA Corporate
# 7                              HelloFresh
# 8                      Concept Technology
# 9                                  Google
# 10                        Clinica Tepeyac
# 11                   DaVita Medical Group
# 12                      AAS Services, LLC
# 13               Tundra Restaurant Supply
# ..                                    ...
# 4                                   UpTop
# 5                                   MoGVL
# 6                            Sportsrocket
# 7                         Alaska Airlines
# 8                            Zillow Group
# 9                                Rival IQ
# 10               University of Washington
# 11               University of Washington
# 12                                Dropbox
# 13                              Microsoft
# 14                                   Uber
# 15                          Costco Travel
# 16                            HealthSlate
# 0                          GiveCrypto.org
# 1                          Marin Software
# 2                   AHNP Precision Health
# 3                            Aperio Group
# 4                              FortressIQ
# 5                                   Shell
# 6                          GiveCrypto.org
# 7                              Fleetsmith
# 8                                 Dropbox
# 9                                   Honor
# 10                         Extracker, Inc
# 11                                Dropbox
# 12                                 Square
# 13             Highlands Point Apartments
# 14                           Accolite Inc
# 15                              OpenTable
# 16                              Accenture
#
#                                           Location  \
# 0                                             None
# 1                                             None
# 2                                             None
# 3                                             None
# 4                                       Denver, CO
# 5      Denver, CO 80224 (Southeastern Denver area)
# 6                     Denver, CO 80202 (Lodo area)
# 7          Denver, CO 80216 (Northern Denver area)
# 8                                       Denver, CO
# 9             Aurora, CO 80011 (Norfolk Glen area)
# 10                              Lakewood, CO 80401
# 11                                Aurora, CO 80015
# 12                    Denver, CO 80202 (Lodo area)
# 13                                      Denver, CO
# 14                                            None
# 15                                            None
# 0                                             None
# 1                                             None
# 2                                             None
# 3                                             None
# 4                                             None
# 5                                     Longmont, CO
# 6                                       Denver, CO
# 7                                      Boulder, CO
# 8                                       Denver, CO
# 9                                Boulder, CO 80302
# 10         Denver, CO 80216 (Northern Denver area)
# 11                    Denver, CO 80202 (Lodo area)
# 12                              Lakewood, CO 80401
# 13                               Boulder, CO 80301
# ..                                             ...
# 4                                             None
# 5                                     Bellevue, WA
# 6                                     Bellevue, WA
# 7                Seattle, WA 98194 (Downtown area)
# 8                Seattle, WA 98101 (Downtown area)
# 9                                      Seattle, WA
# 10                                     Seattle, WA
# 11                                     Seattle, WA
# 12                                     Seattle, WA
# 13                                     Redmond, WA
# 14               Seattle, WA 98101 (Downtown area)
# 15                                            None
# 16                                            None
# 0                                             None
# 1                                             None
# 2                                             None
# 3                                             None
# 4                                             None
# 5                                San Francisco, CA
# 6                                San Francisco, CA
# 7                                San Francisco, CA
# 8          San Francisco, CA 94102 (Downtown area)
# 9                                San Francisco, CA
# 10                               San Francisco, CA
# 11         San Francisco, CA 94102 (Downtown area)
# 12  San Francisco, CA 94103 (South Of Market area)
# 13             Oakland, CA 94601 (Harrington area)
# 14                               San Francisco, CA
# 15                                            None
# 16                                            None
#
#                                           Description  \
# 0   Manages data quality of the data warehouse, wo...
# 1   A successful Business Intelligence Data Analys...
# 2   3 years’ experience working with healthcare da...
# 3   The Data Analyst is responsible for data analy...
# 4   Data Analyst(Job Number:. Present data formall...
# 5   Cardwell Beach, the world's best new marketing...
# 6   Over 5 years of specific experience within the...
# 7   3 years’ experience working with healthcare da...
# 8   Our rapidly growing staffing company is active...
# 9   You will utilize advanced scripting techniques...
# 10  The Data Analyst will help manage large datase...
# 11  Proven working experience as a data analyst. T...
# 12  Identify issues related to data, data sources,...
# 13  Working with large data sets, data collection/...
# 14  Data Analyst Responsibilities:. System One is ...
# 15  Interacts with prior servicers and investors r...
# 0   Manages data quality of the data warehouse, wo...
# 1   Data Analyst Responsibilities:. System One is ...
# 2   A minimum of 5 years' experience data analysis...
# 3   They love using data to uncover secrets and tr...
# 4   Proficiency with data entry and computer appli...
# 5   The Associate Data Analyst is responsible for ...
# 6   Data Analyst(Job Number:. Present data formall...
# 7   Two years experience in an analyst role. Quali...
# 8   Our rapidly growing staffing company is active...
# 9   Analyze data and assist in identifying opportu...
# 10  3 years’ experience working with healthcare da...
# 11  Over 5 years of specific experience within the...
# 12  The Data Analyst will help manage large datase...
# 13  The role is part of the Project Management org...
# ..                                                ...
# 4   UpTop has an exciting opportunity for the righ...
# 5   We are looking for a Software Developer to wor...
# 6   We’re looking for a talented Junior Full Stack...
# 7   Contributes as a developer on a scrum delivery...
# 8   As a developer on this team, you will:. We're ...
# 9   Our technology stack includes Node.js, Heroku,...
# 10  UW-IT has an outstanding full time opportunity...
# 11  The University of Washington’s Office of Resea...
# 12  2+ years of full stack software engineering an...
# 13  The candidate should have experience building ...
# 14  Fares is a full stack team with two product-ce...
# 15  Costco Travel is a FULL STACK, fast paced, gro...
# 16  We are looking for a qualified full stack deve...
# 0   GiveCrypto’s mission is to financially empower...
# 1   Full Stack Software Engineer. Marin Software i...
# 2   Full Stack Developer*. Minimum 2-4 years of fu...
# 3   We will consider applicants with solid full st...
# 4   Full Stack Software Development:. At FortressI...
# 5   We’re looking for a Junior React / Full Stack ...
# 6   GiveCrypto’s mission is to financially empower...
# 7   , please include a smiley face :) in front of ...
# 8   2+ years of full stack software engineering an...
# 9   Experience operating at all levels of the stac...
# 10  Full stack developer:. Specifically, we're an ...
# 11  As an Internationalization Developer, you will...
# 12  We are a full stack team, spanning across engi...
# 13  So, if you are a Senior Full Stack Developer w...
# 14  Full stack Developer. Have good experience bui...
# 15  Senior Full Stack Software Engineer. The role ...
# 16  Join Accenture and help transform leading orga...
#
#                                                  URLs        cityJob
# 0   http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...         denver
# 1   http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...         denver
# 2   http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...         denver
# 3   http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...         denver
# 4   http://www.indeed.com/rc/clk?jk=a1930de242bdca...         denver
# 5   http://www.indeed.com/rc/clk?jk=abd4c090c483bb...         denver
# 6   http://www.indeed.com/rc/clk?jk=07ec58ba9cfc0c...         denver
# 7   http://www.indeed.com/company/Clinica-Tepeyac/...         denver
# 8   http://www.indeed.com/company/Concept-Technolo...         denver
# 9   http://www.indeed.com/rc/clk?jk=787c59f30d32ff...         denver
# 10  http://www.indeed.com/company/American-Auto-Sh...         denver
# 11  http://www.indeed.com/company/Cherry-Creek-Sch...         denver
# 12  http://www.indeed.com/rc/clk?jk=86378693ffd7ee...         denver
# 13  http://www.indeed.com/rc/clk?jk=11db956154e021...         denver
# 14  http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...         denver
# 15  http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...         denver
# 0   http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...        boulder
# 1   http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...        boulder
# 2   http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...        boulder
# 3   http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...        boulder
# 4   http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...        boulder
# 5   http://www.indeed.com/company/West-Corporation...        boulder
# 6   http://www.indeed.com/rc/clk?jk=a1930de242bdca...        boulder
# 7   http://www.indeed.com/rc/clk?jk=04b0e75b5432a4...        boulder
# 8   http://www.indeed.com/company/Concept-Technolo...        boulder
# 9   http://www.indeed.com/rc/clk?jk=dc573eb3d2a767...        boulder
# 10  http://www.indeed.com/company/Clinica-Tepeyac/...        boulder
# 11  http://www.indeed.com/rc/clk?jk=07ec58ba9cfc0c...        boulder
# 12  http://www.indeed.com/company/American-Auto-Sh...        boulder
# 13  http://www.indeed.com/rc/clk?jk=6b0157a74c228a...        boulder
# ..                                                ...            ...
# 4   http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...        seattle
# 5   http://www.indeed.com/rc/clk?jk=d38ea9bf453c7f...        seattle
# 6   http://www.indeed.com/rc/clk?jk=dfe1a51d15b4ad...        seattle
# 7   http://www.indeed.com/rc/clk?jk=bbc5797926ecb6...        seattle
# 8   http://www.indeed.com/rc/clk?jk=aefa8677b44d39...        seattle
# 9   http://www.indeed.com/company/Rival-IQ/jobs/Fu...        seattle
# 10  http://www.indeed.com/rc/clk?jk=fd9df9cf9f7d79...        seattle
# 11  http://www.indeed.com/rc/clk?jk=06ca461262ce3a...        seattle
# 12  http://www.indeed.com/rc/clk?jk=477176a966d75c...        seattle
# 13  http://www.indeed.com/rc/clk?jk=6373b7885e330c...        seattle
# 14  http://www.indeed.com/rc/clk?jk=ab5522c5f6c39f...        seattle
# 15  http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...        seattle
# 16  http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...        seattle
# 0   http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...  san francisco
# 1   http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...  san francisco
# 2   http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...  san francisco
# 3   http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...  san francisco
# 4   http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...  san francisco
# 5   http://www.indeed.com/rc/clk?jk=6ae7d628d06320...  san francisco
# 6   http://www.indeed.com/company/GiveCrypto.org/j...  san francisco
# 7   http://www.indeed.com/rc/clk?jk=b430d790a92513...  san francisco
# 8   http://www.indeed.com/rc/clk?jk=ab5c0d44465685...  san francisco
# 9   http://www.indeed.com/rc/clk?jk=39e9b477158db7...  san francisco
# 10  http://www.indeed.com/company/Extracker,-Inc/j...  san francisco
# 11  http://www.indeed.com/rc/clk?jk=ac966fbbb0df27...  san francisco
# 12  http://www.indeed.com/rc/clk?jk=262163ce95afb8...  san francisco
# 13  http://www.indeed.com/rc/clk?jk=2c062798196a3c...  san francisco
# 14  http://www.indeed.com/company/Accolite-Inc/job...  san francisco
# 15  http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...  san francisco
# 16  http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...  san francisco
#
# [998 rows x 6 columns]

# %%
# store above data consisting of concatanated dataframes
concat_df=scrapListFrame(jobListSample,cityListSample)

# %%
len(concat_df) 
# 992
# Out:
# 992

# %%
# write scraped data to csv
file_output_csv01 = str(time.strftime("%m-%d-%y")) +str(np.random.randint(1,9+1)) + "-jobs.csv"
concat_df.to_csv("csv/" + file_output_csv01, encoding="utf-8")

# %%
concat_dict = concat_df.to_dict('records')
# converted a dataframe object to list of dicts for mongoDB
# db.insert_many(concat_df.to_dict('records'))

# %%
out = concat_df.to_json(orient='records')[1:-1].replace('},{', '} {')
# type(out) returns STR

# %%
# run below to store JSON formatted data
# with open('file_name.json', 'w') as f:
#     f.write(out)
